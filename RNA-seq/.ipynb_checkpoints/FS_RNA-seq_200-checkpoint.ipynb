# %% [markdown]
# # IMPORT LIBRARIES

# %%
import glob
import cobra
import os
import time
import numpy as np
import pandas as pd
import seaborn as sns
import umap
import matplotlib.pyplot as plt

# %% [markdown]
# # RECON 3D

# %%
recon3D = cobra.io.load_matlab_model('/Users/claudiavicentecomorera/Desktop/TFG/Data/Recon3D_301/Recon3DModel_301.mat')
recon3D
# Out:
# No defined compartments in model Recon3DModel. Compartments will be deduced heuristically using regular expressions.
# Using regular expression found the following compartments:c, e, g, i, l, m, n, r, x
# <Model Recon3DModel at 0x14e337850>

# %%
recon3D.objective = 'biomass_maintenance'
solution_recon_3D = cobra.flux_analysis.parsimonious.pfba(recon3D)
ov = solution_recon_3D.objective_value
solution_recon_3D
# Out:
# <Solution 276649.865 at 0x17f76d910>

# %% [markdown]
# # FLUXES SIMULATION

# %% [markdown]
# ## SETTING FILE PATHS

# %%
f_path = "/Users/claudiavicentecomorera/Desktop/TFG/Models/RNAseq_200Models/"
file_paths = glob.glob(f_path + "*.mat")

# %%
models = []
solutions = []
times = []

for file_path in file_paths:
    model = cobra.io.load_matlab_model(file_path)
    model.id = os.path.splitext(os.path.basename(file_path))[0].replace("_", "-")
    
    t0 = time.time()  
    model.objective = 'biomass_maintenance'
    solution = cobra.flux_analysis.pfba(model) # cobra.flux_analysis.parsimonious.pfba
    t = time.time()  
    pfba_time = t - t0
    
    print(f"The simulation of {model.id} fluxes takes: {pfba_time} seconds")
    
    models.append(model)
    solutions.append(solution)
    times.append(pfba_time)
# Out:
# No defined compartments in model ContextModel. Compartments will be deduced heuristically using regular expressions.
# Using regular expression found the following compartments:c, e, g, i, l, m, n, r, x
# The simulation of GTEX-1I1GS-0011-R1a-SM-CJI43 fluxes takes: 2.039090871810913 seconds
# No defined compartments in model ContextModel. Compartments will be deduced heuristically using regular expressions.
# Using regular expression found the following compartments:c, e, g, i, l, m, n, r, x
# The simulation of GTEX-1LB8K-0011-R1b-SM-EZ6MV fluxes takes: 1.8401618003845215 seconds
# No defined compartments in model ContextModel. Compartments will be deduced heuristically using regular expressions.
# Using regular expression found the following compartments:c, e, g, i, l, m, n, r, x
# The simulation of GTEX-14JG1-0926-SM-5YY8W fluxes takes: 2.6506807804107666 seconds
# No defined compartments in model ContextModel. Compartments will be deduced heuristically using regular expressions.
# Using regular expression found the following compartments:c, e, g, l, m, n, r, x
# No defined compartments in model ContextModel. Compartments will be deduced heuristically using regular expressions.
# Using regular expression found the following compartments:c, e, g, l, m, n, r, x
# The simulation of GTEX-1H4P4-0011-R1b-SM-CL54V fluxes takes: 1.7417628765106201 seconds
# The simulation of GTEX-XMD2-1026-SM-4WWE8 fluxes takes: 1.9659719467163086 seconds
# No defined compartments in model ContextModel. Compartments will be deduced heuristically using regular expressions.
# Using regular expression found the following compartments:c, e, g, l, m, n, r, x
# No defined compartments in model ContextModel. Compartments will be deduced heuristically using regular expressions.
# Using regular expression found the following compartments:c, e, g, l, m, n, r, x
# The simulation of GTEX-QVUS-0011-R1A-SM-3GAD2 fluxes takes: 1.7677350044250488 seconds
# No defined compartments in model ContextModel. Compartments will be deduced heuristically using regular expressions.
# Using regular expression found the following compartments:c, e, g, l, m, n, r, x
# The simulation of GTEX-P78B-0926-SM-2I5FA fluxes takes: 1.4586870670318604 seconds
# No defined compartments in model ContextModel. Compartments will be deduced heuristically using regular expressions.
# Using regular expression found the following compartments:c, e, g, l, m, n, r, x
# The simulation of GTEX-1I1HK-0011-R1b-SM-CM2T7 fluxes takes: 1.6075119972229004 seconds
# The simulation of GTEX-145LU-0011-R1a-SM-5Q5CE fluxes takes: 2.083122968673706 seconds
# No defined compartments in model ContextModel. Compartments will be deduced heuristically using regular expressions.
# Using regular expression found the following compartments:c, e, g, l, m, n, r, x
# The simulation of GTEX-WFG7-0526-SM-3GIKI fluxes takes: 1.498922348022461 seconds
# No defined compartments in model ContextModel. Compartments will be deduced heuristically using regular expressions.
# Using regular expression found the following compartments:c, e, g, l, m, n, r, x
# The simulation of GTEX-14PK6-0326-SM-6AJ9S fluxes takes: 1.6019928455352783 seconds
# No defined compartments in model ContextModel. Compartments will be deduced heuristically using regular expressions.
# Using regular expression found the following compartments:c, e, g, l, m, n, r, x
# The simulation of GTEX-1212Z-0011-R1b-SM-5BC72 fluxes takes: 1.9553959369659424 seconds
# No defined compartments in model ContextModel. Compartments will be deduced heuristically using regular expressions.
# Using regular expression found the following compartments:c, e, g, i, l, m, n, r, x
# The simulation of GTEX-QDVN-0726-SM-4B64L fluxes takes: 2.5044209957122803 seconds
# No defined compartments in model ContextModel. Compartments will be deduced heuristically using regular expressions.
# Using regular expression found the following compartments:c, e, g, i, l, m, n, r, x
# The simulation of GTEX-T5JC-0011-R1A-SM-32PM6 fluxes takes: 1.5200729370117188 seconds
# No defined compartments in model ContextModel. Compartments will be deduced heuristically using regular expressions.
# Using regular expression found the following compartments:c, e, g, i, l, m, n, r, x
# The simulation of GTEX-1A3MX-0011-R1b-SM-7P8PH fluxes takes: 1.8580410480499268 seconds
# No defined compartments in model ContextModel. Compartments will be deduced heuristically using regular expressions.
# Using regular expression found the following compartments:c, e, g, l, m, n, r, x
# The simulation of GTEX-PLZ5-0726-SM-2I5F9 fluxes takes: 1.7025730609893799 seconds
# No defined compartments in model ContextModel. Compartments will be deduced heuristically using regular expressions.
# Using regular expression found the following compartments:c, e, g, i, l, m, n, r, x
# The simulation of GTEX-15CHQ-0011-R1a-SM-COH27 fluxes takes: 1.9030508995056152 seconds
# No defined compartments in model ContextModel. Compartments will be deduced heuristically using regular expressions.
# Using regular expression found the following compartments:c, e, g, l, m, n, r, x
# The simulation of GTEX-T2IS-0526-SM-32QP9 fluxes takes: 1.7562587261199951 seconds
# No defined compartments in model ContextModel. Compartments will be deduced heuristically using regular expressions.
# Using regular expression found the following compartments:c, e, g, l, m, n, r, x
# No defined compartments in model ContextModel. Compartments will be deduced heuristically using regular expressions.
# Using regular expression found the following compartments:c, e, g, l, m, n, r, x
# The simulation of GTEX-1IDJI-0626-SM-C1YQD fluxes takes: 1.5307519435882568 seconds
# The simulation of GTEX-14A6H-0526-SM-5NQAZ fluxes takes: 1.7350857257843018 seconds
# No defined compartments in model ContextModel. Compartments will be deduced heuristically using regular expressions.
# Using regular expression found the following compartments:c, e, g, i, l, m, n, r, x
# The simulation of GTEX-13NYB-0626-SM-5MR47 fluxes takes: 2.238330841064453 seconds
# No defined compartments in model ContextModel. Compartments will be deduced heuristically using regular expressions.
# Using regular expression found the following compartments:c, e, g, i, l, m, n, r, x
# No defined compartments in model ContextModel. Compartments will be deduced heuristically using regular expressions.
# Using regular expression found the following compartments:c, e, g, l, m, n, r, x
# The simulation of GTEX-14ABY-0011-R1a-SM-6EU2W fluxes takes: 1.7668771743774414 seconds
# No defined compartments in model ContextModel. Compartments will be deduced heuristically using regular expressions.
# Using regular expression found the following compartments:c, e, g, i, l, m, n, r, x
# The simulation of GTEX-VJYA-0326-SM-3GAEX fluxes takes: 1.3353443145751953 seconds
# No defined compartments in model ContextModel. Compartments will be deduced heuristically using regular expressions.
# Using regular expression found the following compartments:c, e, g, l, m, n, r, x
# The simulation of GTEX-NL3H-0011-R1a-SM-48TDJ fluxes takes: 1.7410309314727783 seconds
# The simulation of GTEX-11DZ1-0426-SM-5H11A fluxes takes: 1.321641206741333 seconds
# No defined compartments in model ContextModel. Compartments will be deduced heuristically using regular expressions.
# Using regular expression found the following compartments:c, e, g, i, l, m, n, r, x
# No defined compartments in model ContextModel. Compartments will be deduced heuristically using regular expressions.
# Using regular expression found the following compartments:c, e, g, i, l, m, n, r, x
# The simulation of GTEX-13S7M-2126-SM-5S2QR fluxes takes: 2.217473030090332 seconds
# No defined compartments in model ContextModel. Compartments will be deduced heuristically using regular expressions.
# Using regular expression found the following compartments:c, e, g, i, l, m, n, r, x
# The simulation of GTEX-13112-0011-R1b-SM-5HL7K fluxes takes: 1.5567841529846191 seconds
# The simulation of GTEX-14JIY-0011-R1a-SM-68713 fluxes takes: 2.835824966430664 seconds
# No defined compartments in model ContextModel. Compartments will be deduced heuristically using regular expressions.
# Using regular expression found the following compartments:c, e, g, i, l, m, n, r, x
# The simulation of GTEX-13O3Q-0011-R1b-SM-5KM3L fluxes takes: 1.761000156402588 seconds
# No defined compartments in model ContextModel. Compartments will be deduced heuristically using regular expressions.
# Using regular expression found the following compartments:c, e, g, i, l, m, n, r, x
# No defined compartments in model ContextModel. Compartments will be deduced heuristically using regular expressions.
# Using regular expression found the following compartments:c, e, g, i, l, m, n, r, x
# The simulation of GTEX-X4EP-0011-R1A-SM-3P624 fluxes takes: 2.052216053009033 seconds
# No defined compartments in model ContextModel. Compartments will be deduced heuristically using regular expressions.
# Using regular expression found the following compartments:c, e, g, l, m, n, r, x
# The simulation of GTEX-1F75A-0011-R1b-SM-CE6RA fluxes takes: 1.6207449436187744 seconds
# No defined compartments in model ContextModel. Compartments will be deduced heuristically using regular expressions.
# Using regular expression found the following compartments:c, e, g, l, m, n, r, x
# The simulation of GTEX-OIZF-0526-SM-7MXVM fluxes takes: 1.5055890083312988 seconds
# The simulation of GTEX-18A6Q-0011-R1b-SM-731DI fluxes takes: 1.9178690910339355 seconds
# No defined compartments in model ContextModel. Compartments will be deduced heuristically using regular expressions.
# Using regular expression found the following compartments:c, e, g, i, l, m, n, r, x
# The simulation of GTEX-WRHU-0226-SM-3MJFV fluxes takes: 2.6416079998016357 seconds
# No defined compartments in model ContextModel. Compartments will be deduced heuristically using regular expressions.
# Using regular expression found the following compartments:c, e, g, i, l, m, n, r, x
# The simulation of GTEX-13CF2-0011-R1a-SM-5LZY1 fluxes takes: 1.8805451393127441 seconds
# No defined compartments in model ContextModel. Compartments will be deduced heuristically using regular expressions.
# Using regular expression found the following compartments:c, e, g, l, m, n, r, x
# No defined compartments in model ContextModel. Compartments will be deduced heuristically using regular expressions.
# Using regular expression found the following compartments:c, e, g, l, m, n, r, x
# The simulation of GTEX-14PJM-0926-SM-6AJ9Y fluxes takes: 1.457746982574463 seconds
# The simulation of GTEX-1GMR3-0226-SM-7RHIB fluxes takes: 1.4252879619598389 seconds
# No defined compartments in model ContextModel. Compartments will be deduced heuristically using regular expressions.
# Using regular expression found the following compartments:c, e, g, i, l, m, n, r, x
# No defined compartments in model ContextModel. Compartments will be deduced heuristically using regular expressions.
# Using regular expression found the following compartments:c, e, g, l, m, n, r, x
# The simulation of GTEX-1A8G6-0011-R1a-SM-7P8PC fluxes takes: 1.6553089618682861 seconds
# No defined compartments in model ContextModel. Compartments will be deduced heuristically using regular expressions.
# Using regular expression found the following compartments:c, e, g, i, l, m, n, r, x
# The simulation of GTEX-11EI6-0826-SM-5985V fluxes takes: 1.3631579875946045 seconds
# No defined compartments in model ContextModel. Compartments will be deduced heuristically using regular expressions.
# Using regular expression found the following compartments:c, e, g, l, m, n, r, x
# The simulation of GTEX-1AX9I-0011-R1b-SM-7RHG2 fluxes takes: 1.6996119022369385 seconds
# The simulation of GTEX-XMD1-0011-R1A-SM-4AT4C fluxes takes: 1.6361851692199707 seconds
# No defined compartments in model ContextModel. Compartments will be deduced heuristically using regular expressions.
# Using regular expression found the following compartments:c, e, g, l, m, n, r, x
# The simulation of GTEX-1HR98-0011-R1a-SM-ARZLQ fluxes takes: 2.055267095565796 seconds
# No defined compartments in model ContextModel. Compartments will be deduced heuristically using regular expressions.
# Using regular expression found the following compartments:c, e, g, i, l, m, n, r, x
# The simulation of GTEX-1EWIQ-0011-R1a-SM-9OSX7 fluxes takes: 1.5853509902954102 seconds
# No defined compartments in model ContextModel. Compartments will be deduced heuristically using regular expressions.
# Using regular expression found the following compartments:c, e, g, l, m, n, r, x
# The simulation of GTEX-18A6Q-0826-SM-7KFRD fluxes takes: 1.4030430316925049 seconds
# No defined compartments in model ContextModel. Compartments will be deduced heuristically using regular expressions.
# Using regular expression found the following compartments:c, e, g, i, l, m, n, r, x
# The simulation of GTEX-11GS4-0011-R1a-SM-DO129 fluxes takes: 1.8570160865783691 seconds
# No defined compartments in model ContextModel. Compartments will be deduced heuristically using regular expressions.
# Using regular expression found the following compartments:c, e, g, i, l, m, n, r, x
# The simulation of GTEX-1F6IF-0011-R1b-SM-9WG78 fluxes takes: 1.7340710163116455 seconds
# No defined compartments in model ContextModel. Compartments will be deduced heuristically using regular expressions.
# Using regular expression found the following compartments:c, e, g, l, m, n, r, x
# The simulation of GTEX-17KNJ-0926-SM-7IGP2 fluxes takes: 1.6656079292297363 seconds
# No defined compartments in model ContextModel. Compartments will be deduced heuristically using regular expressions.
# Using regular expression found the following compartments:c, e, g, i, l, m, n, r, x
# The simulation of GTEX-1C6VQ-0011-R1a-SM-7P8Q2 fluxes takes: 2.0100772380828857 seconds
# No defined compartments in model ContextModel. Compartments will be deduced heuristically using regular expressions.
# Using regular expression found the following compartments:c, e, g, l, m, n, r, x
# The simulation of GTEX-11GSP-0011-R1a-SM-9QEJ3 fluxes takes: 2.607110023498535 seconds
# No defined compartments in model ContextModel. Compartments will be deduced heuristically using regular expressions.
# Using regular expression found the following compartments:c, e, g, l, m, n, r, x
# The simulation of GTEX-1I1GV-0011-R1a-SM-CL559 fluxes takes: 1.6413569450378418 seconds
# No defined compartments in model ContextModel. Compartments will be deduced heuristically using regular expressions.
# Using regular expression found the following compartments:c, e, g, i, l, m, n, r, x
# No defined compartments in model ContextModel. Compartments will be deduced heuristically using regular expressions.
# Using regular expression found the following compartments:c, e, g, l, m, n, r, x
# The simulation of GTEX-1313W-0011-R1b-SM-5EQ4A fluxes takes: 1.6617159843444824 seconds
# The simulation of GTEX-15UF6-0011-R1a-SM-9QEGH fluxes takes: 1.6701078414916992 seconds
# No defined compartments in model ContextModel. Compartments will be deduced heuristically using regular expressions.
# Using regular expression found the following compartments:c, e, g, i, l, m, n, r, x
# No defined compartments in model ContextModel. Compartments will be deduced heuristically using regular expressions.
# Using regular expression found the following compartments:c, e, g, l, m, n, r, x
# The simulation of GTEX-16YQH-0011-R1a-SM-7LT8R fluxes takes: 2.4048190116882324 seconds
# The simulation of GTEX-1GN2E-0011-R1b-SM-CE6RJ fluxes takes: 1.4114611148834229 seconds
# No defined compartments in model ContextModel. Compartments will be deduced heuristically using regular expressions.
# Using regular expression found the following compartments:c, e, g, i, l, m, n, r, x
# The simulation of GTEX-13FLV-0426-SM-5KLZA fluxes takes: 2.708556890487671 seconds
# No defined compartments in model ContextModel. Compartments will be deduced heuristically using regular expressions.
# Using regular expression found the following compartments:c, e, g, i, l, m, n, r, x
# The simulation of GTEX-11ZVC-0011-R1b-SM-5BC6M fluxes takes: 1.8367180824279785 seconds
# No defined compartments in model ContextModel. Compartments will be deduced heuristically using regular expressions.
# Using regular expression found the following compartments:c, e, g, i, l, m, n, r, x
# No defined compartments in model ContextModel. Compartments will be deduced heuristically using regular expressions.
# Using regular expression found the following compartments:c, e, g, l, m, n, r, x
# The simulation of GTEX-13N1W-0011-R1b-SM-5MR4T fluxes takes: 2.3628218173980713 seconds
# No defined compartments in model ContextModel. Compartments will be deduced heuristically using regular expressions.
# Using regular expression found the following compartments:c, e, g, l, m, n, r, x
# The simulation of GTEX-13OW5-0011-R1b-SM-5L3GE fluxes takes: 1.7924399375915527 seconds
# No defined compartments in model ContextModel. Compartments will be deduced heuristically using regular expressions.
# Using regular expression found the following compartments:c, e, g, l, m, n, r, x
# The simulation of GTEX-X5EB-0426-SM-46MVY fluxes takes: 1.6143341064453125 seconds
# No defined compartments in model ContextModel. Compartments will be deduced heuristically using regular expressions.
# Using regular expression found the following compartments:c, e, g, l, m, n, r, x
# The simulation of GTEX-TML8-0326-SM-4GICN fluxes takes: 1.5386459827423096 seconds
# The simulation of GTEX-XPVG-1026-SM-4B64Y fluxes takes: 1.5474910736083984 seconds
# No defined compartments in model ContextModel. Compartments will be deduced heuristically using regular expressions.
# Using regular expression found the following compartments:c, e, g, i, l, m, n, r, x
# No defined compartments in model ContextModel. Compartments will be deduced heuristically using regular expressions.
# Using regular expression found the following compartments:c, e, g, l, m, n, r, x
# The simulation of GTEX-12BJ1-1026-SM-5EGJA fluxes takes: 2.101795196533203 seconds
# No defined compartments in model ContextModel. Compartments will be deduced heuristically using regular expressions.
# Using regular expression found the following compartments:c, e, g, l, m, n, r, x
# The simulation of GTEX-13FTZ-0526-SM-5IJCW fluxes takes: 1.4877419471740723 seconds
# The simulation of GTEX-11DXZ-0726-SM-5N9C4 fluxes takes: 1.654148817062378 seconds
# No defined compartments in model ContextModel. Compartments will be deduced heuristically using regular expressions.
# Using regular expression found the following compartments:c, e, g, i, l, m, n, r, x
# No defined compartments in model ContextModel. Compartments will be deduced heuristically using regular expressions.
# Using regular expression found the following compartments:c, e, g, i, l, m, n, r, x
# The simulation of GTEX-1K9T9-0926-SM-D3L9C fluxes takes: 2.2499120235443115 seconds
# The simulation of GTEX-12WSH-0011-R1a-SM-5GU5V fluxes takes: 1.5807507038116455 seconds
# No defined compartments in model ContextModel. Compartments will be deduced heuristically using regular expressions.
# Using regular expression found the following compartments:c, e, g, l, m, n, r, x
# The simulation of GTEX-RU72-0526-SM-2TF5Z fluxes takes: 1.7856810092926025 seconds
# No defined compartments in model ContextModel. Compartments will be deduced heuristically using regular expressions.
# Using regular expression found the following compartments:c, e, g, l, m, n, r, x
# No defined compartments in model ContextModel. Compartments will be deduced heuristically using regular expressions.
# Using regular expression found the following compartments:c, e, g, l, m, n, r, x
# The simulation of GTEX-11TUW-0011-R1a-SM-DO92S fluxes takes: 1.6041069030761719 seconds
# The simulation of GTEX-1H11D-0726-SM-9OSWA fluxes takes: 1.7011480331420898 seconds
# No defined compartments in model ContextModel. Compartments will be deduced heuristically using regular expressions.
# Using regular expression found the following compartments:c, e, g, i, l, m, n, r, x
# The simulation of GTEX-ZVT3-0926-SM-5GICK fluxes takes: 2.2666218280792236 seconds
# No defined compartments in model ContextModel. Compartments will be deduced heuristically using regular expressions.
# Using regular expression found the following compartments:c, e, g, i, l, m, n, r, x
# The simulation of GTEX-11ONC-0011-R1a-SM-57WD4 fluxes takes: 8.317264080047607 seconds
# No defined compartments in model ContextModel. Compartments will be deduced heuristically using regular expressions.
# Using regular expression found the following compartments:c, e, g, l, m, n, r, x
# The simulation of GTEX-ZF28-0011-R1a-SM-4WWD1 fluxes takes: 1.8364739418029785 seconds
# No defined compartments in model ContextModel. Compartments will be deduced heuristically using regular expressions.
# Using regular expression found the following compartments:c, e, g, i, l, m, n, r, x
# The simulation of GTEX-11DXW-0011-R1a-SM-DNZZD fluxes takes: 1.9226810932159424 seconds
# No defined compartments in model ContextModel. Compartments will be deduced heuristically using regular expressions.
# Using regular expression found the following compartments:c, e, g, l, m, n, r, x
# The simulation of GTEX-132Q8-0011-R1a-SM-5EGLK fluxes takes: 1.9225990772247314 seconds
# No defined compartments in model ContextModel. Compartments will be deduced heuristically using regular expressions.
# Using regular expression found the following compartments:c, e, g, l, m, n, r, x
# The simulation of GTEX-1GN1W-1026-SM-9OSW2 fluxes takes: 1.5506641864776611 seconds
# No defined compartments in model ContextModel. Compartments will be deduced heuristically using regular expressions.
# Using regular expression found the following compartments:c, e, g, i, l, m, n, r, x
# The simulation of GTEX-X585-0011-R1B-SM-46MVE fluxes takes: 1.6622190475463867 seconds
# No defined compartments in model ContextModel. Compartments will be deduced heuristically using regular expressions.
# Using regular expression found the following compartments:c, e, g, i, l, m, n, r, x
# The simulation of GTEX-1B996-0011-R1b-SM-7P8PO fluxes takes: 2.1931979656219482 seconds
# No defined compartments in model ContextModel. Compartments will be deduced heuristically using regular expressions.
# Using regular expression found the following compartments:c, e, g, l, m, n, r, x
# The simulation of GTEX-1HCUA-0226-SM-A8N88 fluxes takes: 1.6508228778839111 seconds
# No defined compartments in model ContextModel. Compartments will be deduced heuristically using regular expressions.
# Using regular expression found the following compartments:c, e, g, i, l, m, n, r, x
# The simulation of GTEX-13X6I-0011-R1b-SM-5PNZC fluxes takes: 1.5373740196228027 seconds
# No defined compartments in model ContextModel. Compartments will be deduced heuristically using regular expressions.
# Using regular expression found the following compartments:c, e, g, i, l, m, n, r, x
# The simulation of GTEX-WZTO-0011-R1B-SM-3NMAR fluxes takes: 1.5968139171600342 seconds
# No defined compartments in model ContextModel. Compartments will be deduced heuristically using regular expressions.
# Using regular expression found the following compartments:c, e, g, l, m, n, r, x
# The simulation of GTEX-17F98-0226-SM-793BV fluxes takes: 1.6102588176727295 seconds
# No defined compartments in model ContextModel. Compartments will be deduced heuristically using regular expressions.
# Using regular expression found the following compartments:c, e, g, i, l, m, n, r, x
# No defined compartments in model ContextModel. Compartments will be deduced heuristically using regular expressions.
# Using regular expression found the following compartments:c, e, g, i, l, m, n, r, x
# The simulation of GTEX-R55G-0826-SM-2TC5U fluxes takes: 2.2340340614318848 seconds
# The simulation of GTEX-13JUV-0011-R1a-SM-5LZY4 fluxes takes: 2.0400662422180176 seconds
# No defined compartments in model ContextModel. Compartments will be deduced heuristically using regular expressions.
# Using regular expression found the following compartments:c, e, g, l, m, n, r, x
# The simulation of GTEX-148VI-0226-SM-5RQKA fluxes takes: 1.7265939712524414 seconds
# No defined compartments in model ContextModel. Compartments will be deduced heuristically using regular expressions.
# Using regular expression found the following compartments:c, e, g, i, l, m, n, r, x
# No defined compartments in model ContextModel. Compartments will be deduced heuristically using regular expressions.
# The simulation of GTEX-1ICLY-0926-SM-CM2RJ fluxes takes: 1.5963468551635742 seconds
# Using regular expression found the following compartments:c, e, g, i, l, m, n, r, x
# No defined compartments in model ContextModel. Compartments will be deduced heuristically using regular expressions.
# Using regular expression found the following compartments:c, e, g, i, l, m, n, r, x
# The simulation of GTEX-15DCD-0011-R1b-SM-6LPIJ fluxes takes: 1.5631811618804932 seconds
# No defined compartments in model ContextModel. Compartments will be deduced heuristically using regular expressions.
# Using regular expression found the following compartments:c, e, g, l, m, n, r, x
# The simulation of GTEX-12WSD-0011-R1b-SM-5LZVY fluxes takes: 1.6693389415740967 seconds
# No defined compartments in model ContextModel. Compartments will be deduced heuristically using regular expressions.
# Using regular expression found the following compartments:c, e, g, i, l, m, n, r, x
# The simulation of GTEX-QVJO-0011-R1A-SM-2S1QI fluxes takes: 1.6587417125701904 seconds
# The simulation of GTEX-P44G-0011-R1A-SM-2I3FE fluxes takes: 1.5764811038970947 seconds
# No defined compartments in model ContextModel. Compartments will be deduced heuristically using regular expressions.
# Using regular expression found the following compartments:c, e, g, i, l, m, n, r, x
# The simulation of GTEX-1HGF4-0011-R1a-SM-CJI3S fluxes takes: 2.0187861919403076 seconds
# No defined compartments in model ContextModel. Compartments will be deduced heuristically using regular expressions.
# Using regular expression found the following compartments:c, e, g, l, m, n, r, x
# The simulation of GTEX-U412-0826-SM-3DB9K fluxes takes: 1.6315741539001465 seconds
# No defined compartments in model ContextModel. Compartments will be deduced heuristically using regular expressions.
# Using regular expression found the following compartments:c, e, g, i, l, m, n, r, x
# The simulation of GTEX-1LG7Y-0011-R1a-SM-EYYWV fluxes takes: 1.7671048641204834 seconds
# No defined compartments in model ContextModel. Compartments will be deduced heuristically using regular expressions.
# Using regular expression found the following compartments:c, e, g, i, l, m, n, r, x
# The simulation of GTEX-13FTY-0126-SM-5J2NZ fluxes takes: 2.159389019012451 seconds
# No defined compartments in model ContextModel. Compartments will be deduced heuristically using regular expressions.
# Using regular expression found the following compartments:c, e, g, i, l, m, n, r, x
# No defined compartments in model ContextModel. Compartments will be deduced heuristically using regular expressions.
# Using regular expression found the following compartments:c, e, g, l, m, n, r, x
# The simulation of GTEX-1EMGI-0011-R1b-SM-9OSWZ fluxes takes: 2.100588798522949 seconds
# No defined compartments in model ContextModel. Compartments will be deduced heuristically using regular expressions.
# Using regular expression found the following compartments:c, e, g, l, m, n, r, x
# The simulation of GTEX-YJ8O-1826-SM-5HL82 fluxes takes: 1.5661778450012207 seconds
# The simulation of GTEX-18A67-1126-SM-7KFSB fluxes takes: 1.4590928554534912 seconds
# No defined compartments in model ContextModel. Compartments will be deduced heuristically using regular expressions.
# Using regular expression found the following compartments:c, e, g, i, l, m, n, r, x
# No defined compartments in model ContextModel. Compartments will be deduced heuristically using regular expressions.
# Using regular expression found the following compartments:c, e, g, l, m, n, r, x
# The simulation of GTEX-1GZ2Q-0011-R1a-SM-CJI2Y fluxes takes: 1.952585220336914 seconds
# The simulation of GTEX-146FQ-0926-SM-5LUAV fluxes takes: 1.7731828689575195 seconds
# No defined compartments in model ContextModel. Compartments will be deduced heuristically using regular expressions.
# Using regular expression found the following compartments:c, e, g, l, m, n, r, x
# The simulation of GTEX-1S5VW-0926-SM-EWRNU fluxes takes: 1.4601070880889893 seconds
# No defined compartments in model ContextModel. Compartments will be deduced heuristically using regular expressions.
# Using regular expression found the following compartments:c, e, g, l, m, n, r, x
# No defined compartments in model ContextModel. Compartments will be deduced heuristically using regular expressions.
# Using regular expression found the following compartments:c, e, g, l, m, n, r, x
# The simulation of GTEX-13FTY-0011-R1a-SM-5LZXE fluxes takes: 1.7885398864746094 seconds
# The simulation of GTEX-13N11-0326-SM-5LUA3 fluxes takes: 1.5843071937561035 seconds
# No defined compartments in model ContextModel. Compartments will be deduced heuristically using regular expressions.
# Using regular expression found the following compartments:c, e, g, i, l, m, n, r, x
# The simulation of GTEX-11WQK-1226-SM-5GU5Z fluxes takes: 2.212557077407837 seconds
# No defined compartments in model ContextModel. Compartments will be deduced heuristically using regular expressions.
# Using regular expression found the following compartments:c, e, g, l, m, n, r, x
# The simulation of GTEX-14LLW-0726-SM-5ZZVV fluxes takes: 1.6531858444213867 seconds
# No defined compartments in model ContextModel. Compartments will be deduced heuristically using regular expressions.
# Using regular expression found the following compartments:c, e, g, i, l, m, n, r, x
# The simulation of GTEX-1F7RK-0826-SM-7SB8V fluxes takes: 2.5624499320983887 seconds
# No defined compartments in model ContextModel. Compartments will be deduced heuristically using regular expressions.
# Using regular expression found the following compartments:c, e, g, i, l, m, n, r, x
# The simulation of GTEX-XQ3S-0926-SM-4BOPI fluxes takes: 2.908841133117676 seconds
# No defined compartments in model ContextModel. Compartments will be deduced heuristically using regular expressions.
# Using regular expression found the following compartments:c, e, g, i, l, m, n, r, x
# No defined compartments in model ContextModel. Compartments will be deduced heuristically using regular expressions.
# Using regular expression found the following compartments:c, e, g, l, m, n, r, x
# The simulation of GTEX-1H1ZS-0011-R1b-SM-A9G1E fluxes takes: 2.5403661727905273 seconds
# The simulation of GTEX-ZYW4-1526-SM-5SIBA fluxes takes: 1.6641490459442139 seconds
# No defined compartments in model ContextModel. Compartments will be deduced heuristically using regular expressions.
# Using regular expression found the following compartments:c, e, g, i, l, m, n, r, x
# No defined compartments in model ContextModel. Compartments will be deduced heuristically using regular expressions.
# Using regular expression found the following compartments:c, e, g, i, l, m, n, r, x
# The simulation of GTEX-1B933-0011-R1b-SM-9QEGW fluxes takes: 1.7889540195465088 seconds
# The simulation of GTEX-1GF9W-0011-R1a-SM-9QEIQ fluxes takes: 1.6379690170288086 seconds
# No defined compartments in model ContextModel. Compartments will be deduced heuristically using regular expressions.
# Using regular expression found the following compartments:c, e, g, i, l, m, n, r, x
# The simulation of GTEX-13OW6-0826-SM-5L3GA fluxes takes: 2.265838146209717 seconds
# No defined compartments in model ContextModel. Compartments will be deduced heuristically using regular expressions.
# Using regular expression found the following compartments:c, e, g, i, l, m, n, r, x
# No defined compartments in model ContextModel. Compartments will be deduced heuristically using regular expressions.
# Using regular expression found the following compartments:c, e, g, l, m, n, r, x
# The simulation of GTEX-1HSKV-0011-R1b-SM-CMKH7 fluxes takes: 1.7175350189208984 seconds
# No defined compartments in model ContextModel. Compartments will be deduced heuristically using regular expressions.
# Using regular expression found the following compartments:c, e, g, l, m, n, r, x
# The simulation of GTEX-ZA64-0326-SM-5HL8T fluxes takes: 1.4982669353485107 seconds
# No defined compartments in model ContextModel. Compartments will be deduced heuristically using regular expressions.
# Using regular expression found the following compartments:c, e, g, l, m, n, r, x
# The simulation of GTEX-1GTWX-0626-SM-9WYU1 fluxes takes: 1.8454389572143555 seconds
# No defined compartments in model ContextModel. Compartments will be deduced heuristically using regular expressions.
# Using regular expression found the following compartments:c, e, g, l, m, n, r, x
# The simulation of GTEX-QEL4-0826-SM-3GAF2 fluxes takes: 1.5609478950500488 seconds
# No defined compartments in model ContextModel. Compartments will be deduced heuristically using regular expressions.
# Using regular expression found the following compartments:c, e, g, i, l, m, n, r, x
# The simulation of GTEX-14DAQ-0926-SM-793AZ fluxes takes: 1.432370901107788 seconds
# No defined compartments in model ContextModel. Compartments will be deduced heuristically using regular expressions.
# Using regular expression found the following compartments:c, e, g, l, m, n, r, x
# The simulation of GTEX-N7MT-0011-R1a-SM-CNPO1 fluxes takes: 1.7281458377838135 seconds
# The simulation of GTEX-13RTJ-1126-SM-5S2UJ fluxes takes: 1.428748607635498 seconds
# No defined compartments in model ContextModel. Compartments will be deduced heuristically using regular expressions.
# Using regular expression found the following compartments:c, e, g, l, m, n, r, x
# No defined compartments in model ContextModel. Compartments will be deduced heuristically using regular expressions.
# Using regular expression found the following compartments:c, e, g, l, m, n, r, x
# The simulation of GTEX-13QJC-0011-R1b-SM-5S2UU fluxes takes: 1.703812837600708 seconds
# No defined compartments in model ContextModel. Compartments will be deduced heuristically using regular expressions.
# Using regular expression found the following compartments:c, e, g, i, l, m, n, r, x
# The simulation of GTEX-1313W-0926-SM-5EQ56 fluxes takes: 1.553175687789917 seconds
# The simulation of GTEX-13FXS-0011-R1a-SM-5K7U6 fluxes takes: 1.5887680053710938 seconds
# No defined compartments in model ContextModel. Compartments will be deduced heuristically using regular expressions.
# Using regular expression found the following compartments:c, e, g, i, l, m, n, r, x
# No defined compartments in model ContextModel. Compartments will be deduced heuristically using regular expressions.
# Using regular expression found the following compartments:c, e, g, l, m, n, r, x
# The simulation of GTEX-1GN1U-0011-R1a-SM-CJI25 fluxes takes: 1.6895780563354492 seconds
# The simulation of GTEX-1477Z-0626-SM-5NQB7 fluxes takes: 1.2372257709503174 seconds
# No defined compartments in model ContextModel. Compartments will be deduced heuristically using regular expressions.
# Using regular expression found the following compartments:c, e, g, i, l, m, n, r, x
# The simulation of GTEX-1E2YA-0926-SM-7MXUK fluxes takes: 2.338747024536133 seconds
# No defined compartments in model ContextModel. Compartments will be deduced heuristically using regular expressions.
# Using regular expression found the following compartments:c, e, g, i, l, m, n, r, x
# The simulation of GTEX-1IL2U-0926-SM-CKZOB fluxes takes: 2.356210947036743 seconds
# No defined compartments in model ContextModel. Compartments will be deduced heuristically using regular expressions.
# Using regular expression found the following compartments:c, e, g, i, l, m, n, r, x
# The simulation of GTEX-YECK-0926-SM-4W214 fluxes takes: 2.559203863143921 seconds
# No defined compartments in model ContextModel. Compartments will be deduced heuristically using regular expressions.
# Using regular expression found the following compartments:c, e, g, i, l, m, n, r, x
# The simulation of GTEX-YEC4-0526-SM-4W21U fluxes takes: 2.891079902648926 seconds
# No defined compartments in model ContextModel. Compartments will be deduced heuristically using regular expressions.
# Using regular expression found the following compartments:c, e, g, i, l, m, n, r, x
# The simulation of GTEX-1I1GQ-1126-SM-CNNQT fluxes takes: 2.5108509063720703 seconds
# No defined compartments in model ContextModel. Compartments will be deduced heuristically using regular expressions.
# Using regular expression found the following compartments:c, e, g, i, l, m, n, r, x
# The simulation of GTEX-14E6D-0011-R1b-SM-5YYAW fluxes takes: 1.7918691635131836 seconds
# No defined compartments in model ContextModel. Compartments will be deduced heuristically using regular expressions.
# Using regular expression found the following compartments:c, e, g, i, l, m, n, r, x
# The simulation of GTEX-1EKGG-0011-R1b-SM-9QEI1 fluxes takes: 1.8853051662445068 seconds
# No defined compartments in model ContextModel. Compartments will be deduced heuristically using regular expressions.
# Using regular expression found the following compartments:c, e, g, i, l, m, n, r, x
# The simulation of GTEX-1E1VI-0926-SM-7P8T3 fluxes takes: 2.422376871109009 seconds
# No defined compartments in model ContextModel. Compartments will be deduced heuristically using regular expressions.
# Using regular expression found the following compartments:c, e, g, i, l, m, n, r, x
# The simulation of GTEX-P4QS-0526-SM-2I3ET fluxes takes: 2.8760218620300293 seconds
# No defined compartments in model ContextModel. Compartments will be deduced heuristically using regular expressions.
# Using regular expression found the following compartments:c, e, g, l, m, n, r, x
# The simulation of GTEX-11ZTS-0011-R1a-SM-5BC71 fluxes takes: 1.841198205947876 seconds
# No defined compartments in model ContextModel. Compartments will be deduced heuristically using regular expressions.
# Using regular expression found the following compartments:c, e, g, i, l, m, n, r, x
# The simulation of GTEX-13NYS-0011-R1b-SM-5MR55 fluxes takes: 1.7490870952606201 seconds
# No defined compartments in model ContextModel. Compartments will be deduced heuristically using regular expressions.
# Using regular expression found the following compartments:c, e, g, i, l, m, n, r, x
# The simulation of GTEX-13N2G-0011-R1b-SM-5MR3G fluxes takes: 1.5942089557647705 seconds
# No defined compartments in model ContextModel. Compartments will be deduced heuristically using regular expressions.
# Using regular expression found the following compartments:c, e, g, i, l, m, n, r, x
# No defined compartments in model ContextModel. Compartments will be deduced heuristically using regular expressions.
# Using regular expression found the following compartments:c, e, g, l, m, n, r, x
# The simulation of GTEX-14E6E-0426-SM-73KUE fluxes takes: 2.4275801181793213 seconds
# The simulation of GTEX-17F96-0626-SM-793CC fluxes takes: 1.3798749446868896 seconds
# No defined compartments in model ContextModel. Compartments will be deduced heuristically using regular expressions.
# Using regular expression found the following compartments:c, e, g, i, l, m, n, r, x
# The simulation of GTEX-PWO3-0011-R1A-SM-2I5EW fluxes takes: 2.029879093170166 seconds
# No defined compartments in model ContextModel. Compartments will be deduced heuristically using regular expressions.
# Using regular expression found the following compartments:c, e, g, l, m, n, r, x
# The simulation of GTEX-17EVQ-0011-R1a-SM-7189S fluxes takes: 1.8214690685272217 seconds
# No defined compartments in model ContextModel. Compartments will be deduced heuristically using regular expressions.
# Using regular expression found the following compartments:c, e, g, l, m, n, r, x
# No defined compartments in model ContextModel. Compartments will be deduced heuristically using regular expressions.
# Using regular expression found the following compartments:c, e, g, l, m, n, r, x
# The simulation of GTEX-13D11-0326-SM-5LZXX fluxes takes: 1.9921181201934814 seconds
# No defined compartments in model ContextModel. Compartments will be deduced heuristically using regular expressions.
# The simulation of GTEX-1J1R8-0226-SM-AHZ3C fluxes takes: 1.7244300842285156 seconds
# Using regular expression found the following compartments:c, e, g, l, m, n, r, x
# No defined compartments in model ContextModel. Compartments will be deduced heuristically using regular expressions.
# Using regular expression found the following compartments:c, e, g, l, m, n, r, x
# The simulation of GTEX-1HBPI-0011-R1b-SM-A9SKF fluxes takes: 1.7582159042358398 seconds
# The simulation of GTEX-ZYVF-1726-SM-5E443 fluxes takes: 1.5360996723175049 seconds
# No defined compartments in model ContextModel. Compartments will be deduced heuristically using regular expressions.
# Using regular expression found the following compartments:c, e, g, i, l, m, n, r, x
# The simulation of GTEX-18A66-0926-SM-718BG fluxes takes: 2.1893060207366943 seconds
# No defined compartments in model ContextModel. Compartments will be deduced heuristically using regular expressions.
# Using regular expression found the following compartments:c, e, g, i, l, m, n, r, x
# No defined compartments in model ContextModel. Compartments will be deduced heuristically using regular expressions.
# The simulation of GTEX-14C5O-0011-R1b-SM-6AJBW fluxes takes: 1.5601999759674072 seconds
# Using regular expression found the following compartments:c, e, g, i, l, m, n, r, x
# The simulation of GTEX-OHPN-0011-R1A-SM-2I5GB fluxes takes: 13.865468978881836 seconds
# No defined compartments in model ContextModel. Compartments will be deduced heuristically using regular expressions.
# Using regular expression found the following compartments:c, e, g, l, m, n, r, x
# The simulation of GTEX-REY6-0426-SM-2TF5G fluxes takes: 1.5755350589752197 seconds
# No defined compartments in model ContextModel. Compartments will be deduced heuristically using regular expressions.
# Using regular expression found the following compartments:c, e, g, l, m, n, r, x
# No defined compartments in model ContextModel. Compartments will be deduced heuristically using regular expressions.
# Using regular expression found the following compartments:c, e, g, l, m, n, r, x
# The simulation of GTEX-ZUA1-1026-SM-4YCEA fluxes takes: 1.5172863006591797 seconds
# No defined compartments in model ContextModel. Compartments will be deduced heuristically using regular expressions.
# Using regular expression found the following compartments:c, e, g, l, m, n, r, x
# The simulation of GTEX-139T8-0011-R1a-SM-5HL75 fluxes takes: 1.6071858406066895 seconds
# No defined compartments in model ContextModel. Compartments will be deduced heuristically using regular expressions.
# Using regular expression found the following compartments:c, e, g, i, l, m, n, r, x
# The simulation of GTEX-1LGRB-0226-SM-CNPQK fluxes takes: 1.6171131134033203 seconds
# The simulation of GTEX-1GN73-0011-R1a-SM-CKZNT fluxes takes: 1.7170531749725342 seconds
# No defined compartments in model ContextModel. Compartments will be deduced heuristically using regular expressions.
# Using regular expression found the following compartments:c, e, g, i, l, m, n, r, x
# The simulation of GTEX-1EX96-0226-SM-7RHHR fluxes takes: 2.6231110095977783 seconds
# No defined compartments in model ContextModel. Compartments will be deduced heuristically using regular expressions.
# Using regular expression found the following compartments:c, e, g, i, l, m, n, r, x
# The simulation of GTEX-17JCI-0011-R1b-SM-718A3 fluxes takes: 1.915482997894287 seconds
# No defined compartments in model ContextModel. Compartments will be deduced heuristically using regular expressions.
# Using regular expression found the following compartments:c, e, g, i, l, m, n, r, x
# The simulation of GTEX-13O3O-0011-R1b-SM-5KM2K fluxes takes: 2.580402135848999 seconds
# No defined compartments in model ContextModel. Compartments will be deduced heuristically using regular expressions.
# Using regular expression found the following compartments:c, e, g, i, l, m, n, r, x
# The simulation of GTEX-ZDXO-0011-R1a-SM-4WKF4 fluxes takes: 1.8065400123596191 seconds
# No defined compartments in model ContextModel. Compartments will be deduced heuristically using regular expressions.
# Using regular expression found the following compartments:c, e, g, i, l, m, n, r, x
# The simulation of GTEX-13OW6-0011-R1a-SM-5L3HQ fluxes takes: 1.829918384552002 seconds
# No defined compartments in model ContextModel. Compartments will be deduced heuristically using regular expressions.
# Using regular expression found the following compartments:c, e, g, i, l, m, n, r, x
# The simulation of GTEX-13FH7-1726-SM-5IJE7 fluxes takes: 2.723587989807129 seconds
# No defined compartments in model ContextModel. Compartments will be deduced heuristically using regular expressions.
# Using regular expression found the following compartments:c, e, g, i, l, m, n, r, x
# The simulation of GTEX-Q2AG-0011-R1A-SM-2HMJI fluxes takes: 2.176945209503174 seconds
# No defined compartments in model ContextModel. Compartments will be deduced heuristically using regular expressions.
# Using regular expression found the following compartments:c, e, g, l, m, n, r, x
# The simulation of GTEX-1JMPZ-1126-SM-ARU8X fluxes takes: 1.5170941352844238 seconds
# No defined compartments in model ContextModel. Compartments will be deduced heuristically using regular expressions.
# Using regular expression found the following compartments:c, e, g, i, l, m, n, r, x
# The simulation of GTEX-13G51-0011-R1a-SM-5LZYR fluxes takes: 1.7911877632141113 seconds
# No defined compartments in model ContextModel. Compartments will be deduced heuristically using regular expressions.
# Using regular expression found the following compartments:c, e, g, i, l, m, n, r, x
# No defined compartments in model ContextModel. Compartments will be deduced heuristically using regular expressions.
# Using regular expression found the following compartments:c, e, g, l, m, n, r, x
# The simulation of GTEX-1B8L1-0011-R1a-SM-7P8SS fluxes takes: 2.5539629459381104 seconds
# The simulation of GTEX-ZE7O-0826-SM-57WCP fluxes takes: 1.7330107688903809 seconds
# No defined compartments in model ContextModel. Compartments will be deduced heuristically using regular expressions.
# Using regular expression found the following compartments:c, e, g, i, l, m, n, r, x
# The simulation of GTEX-OIZG-0526-SM-2HMLF fluxes takes: 2.221374034881592 seconds
# No defined compartments in model ContextModel. Compartments will be deduced heuristically using regular expressions.
# Using regular expression found the following compartments:c, e, g, l, m, n, r, x
# The simulation of GTEX-S7SE-0011-R1A-SM-2XCDE fluxes takes: 1.9435651302337646 seconds
# No defined compartments in model ContextModel. Compartments will be deduced heuristically using regular expressions.
# Using regular expression found the following compartments:c, e, g, l, m, n, r, x
# The simulation of GTEX-13NZA-1426-SM-5KM4Y fluxes takes: 1.5251100063323975 seconds
# No defined compartments in model ContextModel. Compartments will be deduced heuristically using regular expressions.
# Using regular expression found the following compartments:c, e, g, i, l, m, n, r, x
# The simulation of GTEX-111VG-0726-SM-5GIDC fluxes takes: 2.5684680938720703 seconds
# No defined compartments in model ContextModel. Compartments will be deduced heuristically using regular expressions.
# Using regular expression found the following compartments:c, e, g, i, l, m, n, r, x
# The simulation of GTEX-ZUA1-0011-R1a-SM-4YCE2 fluxes takes: 1.7539279460906982 seconds
# No defined compartments in model ContextModel. Compartments will be deduced heuristically using regular expressions.
# Using regular expression found the following compartments:c, e, g, i, l, m, n, r, x
# No defined compartments in model ContextModel. Compartments will be deduced heuristically using regular expressions.
# Using regular expression found the following compartments:c, e, g, l, m, n, r, x
# The simulation of GTEX-1HSMO-0011-R1a-SM-CM2SV fluxes takes: 1.8472330570220947 seconds
# No defined compartments in model ContextModel. Compartments will be deduced heuristically using regular expressions.
# Using regular expression found the following compartments:c, e, g, l, m, n, r, x
# The simulation of GTEX-117YW-0526-SM-5H11C fluxes takes: 1.3164780139923096 seconds
# The simulation of GTEX-139YR-0926-SM-5LZYB fluxes takes: 24.11784601211548 seconds
# No defined compartments in model ContextModel. Compartments will be deduced heuristically using regular expressions.
# Using regular expression found the following compartments:c, e, g, i, l, m, n, r, x
# The simulation of GTEX-YJ89-0011-R1a-SM-4RGLS fluxes takes: 1.8605952262878418 seconds
# No defined compartments in model ContextModel. Compartments will be deduced heuristically using regular expressions.
# Using regular expression found the following compartments:c, e, g, l, m, n, r, x
# The simulation of GTEX-QEG5-1126-SM-33HC2 fluxes takes: 1.5973010063171387 seconds
# No defined compartments in model ContextModel. Compartments will be deduced heuristically using regular expressions.
# Using regular expression found the following compartments:c, e, g, i, l, m, n, r, x
# The simulation of GTEX-13N1W-0726-SM-5MR57 fluxes takes: 2.5036089420318604 seconds
# No defined compartments in model ContextModel. Compartments will be deduced heuristically using regular expressions.
# Using regular expression found the following compartments:c, e, g, i, l, m, n, r, x
# The simulation of GTEX-14E7W-0011-R1b-SM-5YYAT fluxes takes: 1.9020860195159912 seconds
# No defined compartments in model ContextModel. Compartments will be deduced heuristically using regular expressions.
# Using regular expression found the following compartments:c, e, g, i, l, m, n, r, x
# The simulation of GTEX-13FHO-0011-R1b-SM-5KLZG fluxes takes: 1.8030641078948975 seconds
# No defined compartments in model ContextModel. Compartments will be deduced heuristically using regular expressions.
# Using regular expression found the following compartments:c, e, g, i, l, m, n, r, x
# The simulation of GTEX-11ZTS-1226-SM-5EQMQ fluxes takes: 2.426455020904541 seconds
# No defined compartments in model ContextModel. Compartments will be deduced heuristically using regular expressions.
# Using regular expression found the following compartments:c, e, g, l, m, n, r, x
# The simulation of GTEX-13SLW-0011-R1a-SM-5S2W7 fluxes takes: 1.9359550476074219 seconds
# No defined compartments in model ContextModel. Compartments will be deduced heuristically using regular expressions.
# Using regular expression found the following compartments:c, e, g, i, l, m, n, r, x
# The simulation of GTEX-1H3VE-0011-R1a-SM-A9G1K fluxes takes: 2.1983869075775146 seconds
# No defined compartments in model ContextModel. Compartments will be deduced heuristically using regular expressions.
# Using regular expression found the following compartments:c, e, g, i, l, m, n, r, x
# The simulation of GTEX-14XAO-0526-SM-6AJB7 fluxes takes: 1.6477439403533936 seconds
# No defined compartments in model ContextModel. Compartments will be deduced heuristically using regular expressions.
# Using regular expression found the following compartments:c, e, g, l, m, n, r, x
# No defined compartments in model ContextModel. Compartments will be deduced heuristically using regular expressions.
# Using regular expression found the following compartments:c, e, g, l, m, n, r, x
# The simulation of GTEX-13JVG-1426-SM-5MR4W fluxes takes: 1.8413119316101074 seconds
# No defined compartments in model ContextModel. Compartments will be deduced heuristically using regular expressions.
# Using regular expression found the following compartments:c, e, g, l, m, n, r, x
# The simulation of GTEX-NPJ8-0011-R1a-SM-33HCB fluxes takes: 1.5274970531463623 seconds
# No defined compartments in model ContextModel. Compartments will be deduced heuristically using regular expressions.
# Using regular expression found the following compartments:c, e, g, i, l, m, n, r, x
# The simulation of GTEX-16AAH-0426-SM-7DUFM fluxes takes: 1.6215438842773438 seconds
# No defined compartments in model ContextModel. Compartments will be deduced heuristically using regular expressions.
# Using regular expression found the following compartments:c, e, g, l, m, n, r, x
# The simulation of GTEX-12WSM-0011-R1a-SM-5LZW6 fluxes takes: 1.7020208835601807 seconds
# The simulation of GTEX-1QCLY-1026-SM-EWRNI fluxes takes: 1.5884621143341064 seconds
# No defined compartments in model ContextModel. Compartments will be deduced heuristically using regular expressions.
# Using regular expression found the following compartments:c, e, g, i, l, m, n, r, x
# No defined compartments in model ContextModel. Compartments will be deduced heuristically using regular expressions.
# Using regular expression found the following compartments:c, e, g, l, m, n, r, x
# The simulation of GTEX-1E1VI-0011-R1a-SM-ARZMM fluxes takes: 1.7207589149475098 seconds
# No defined compartments in model ContextModel. Compartments will be deduced heuristically using regular expressions.
# Using regular expression found the following compartments:c, e, g, l, m, n, r, x
# The simulation of GTEX-1QEPI-0826-SM-DTX9B fluxes takes: 1.459049940109253 seconds
# No defined compartments in model ContextModel. Compartments will be deduced heuristically using regular expressions.
# Using regular expression found the following compartments:c, e, g, l, m, n, r, x
# The simulation of GTEX-X4XY-1026-SM-46MVX fluxes takes: 1.3888750076293945 seconds
# The simulation of GTEX-1H3O1-0326-SM-9WPO8 fluxes takes: 1.4944770336151123 seconds
# No defined compartments in model ContextModel. Compartments will be deduced heuristically using regular expressions.
# Using regular expression found the following compartments:c, e, g, i, l, m, n, r, x
# No defined compartments in model ContextModel. Compartments will be deduced heuristically using regular expressions.
# Using regular expression found the following compartments:c, e, g, i, l, m, n, r, x
# The simulation of GTEX-14LLW-0011-R1a-SM-5ZZVD fluxes takes: 2.0105860233306885 seconds
# The simulation of GTEX-QMR6-0011-R1A-SM-32PKW fluxes takes: 1.7464368343353271 seconds
# No defined compartments in model ContextModel. Compartments will be deduced heuristically using regular expressions.
# Using regular expression found the following compartments:c, e, g, i, l, m, n, r, x
# The simulation of GTEX-1HT8W-0011-R1b-SM-CJI3V fluxes takes: 1.9214682579040527 seconds
# No defined compartments in model ContextModel. Compartments will be deduced heuristically using regular expressions.
# Using regular expression found the following compartments:c, e, g, i, l, m, n, r, x
# The simulation of GTEX-1B97I-0226-SM-73KVO fluxes takes: 2.1862189769744873 seconds
# No defined compartments in model ContextModel. Compartments will be deduced heuristically using regular expressions.
# Using regular expression found the following compartments:c, e, g, l, m, n, r, x
# The simulation of GTEX-WYVS-0526-SM-3NM9W fluxes takes: 1.8010470867156982 seconds
# No defined compartments in model ContextModel. Compartments will be deduced heuristically using regular expressions.
# Using regular expression found the following compartments:c, e, g, i, l, m, n, r, x
# No defined compartments in model ContextModel. Compartments will be deduced heuristically using regular expressions.
# Using regular expression found the following compartments:c, e, g, l, m, n, r, x
# The simulation of GTEX-1EX96-0011-R1a-SM-CE6R5 fluxes takes: 1.620739221572876 seconds
# The simulation of GTEX-13JUV-0526-SM-5K7XE fluxes takes: 1.4529991149902344 seconds
# No defined compartments in model ContextModel. Compartments will be deduced heuristically using regular expressions.
# Using regular expression found the following compartments:c, e, g, i, l, m, n, r, x
# The simulation of GTEX-14PN4-0011-R1b-SM-69LP8 fluxes takes: 2.7200582027435303 seconds
# No defined compartments in model ContextModel. Compartments will be deduced heuristically using regular expressions.
# Using regular expression found the following compartments:c, e, g, l, m, n, r, x
# The simulation of GTEX-ZTPG-0926-SM-5O99H fluxes takes: 1.550719976425171 seconds
# No defined compartments in model ContextModel. Compartments will be deduced heuristically using regular expressions.
# Using regular expression found the following compartments:c, e, g, i, l, m, n, r, x
# The simulation of GTEX-13FLW-0011-R1b-SM-5LZX2 fluxes takes: 2.228868246078491 seconds
# No defined compartments in model ContextModel. Compartments will be deduced heuristically using regular expressions.
# Using regular expression found the following compartments:c, e, g, l, m, n, r, x
# The simulation of GTEX-1FIGZ-0326-SM-7RHGT fluxes takes: 1.7923119068145752 seconds
# No defined compartments in model ContextModel. Compartments will be deduced heuristically using regular expressions.
# Using regular expression found the following compartments:c, e, g, i, l, m, n, r, x
# The simulation of GTEX-1JMQJ-2126-SM-CNPPA fluxes takes: 2.6354238986968994 seconds
# No defined compartments in model ContextModel. Compartments will be deduced heuristically using regular expressions.
# Using regular expression found the following compartments:c, e, g, l, m, n, r, x
# The simulation of GTEX-P44H-1126-SM-48TBU fluxes takes: 1.688622236251831 seconds

# %%
r_models = pd.DataFrame(index = [model.id for model in models])

for i, solution in enumerate(solutions, start = 0):
    ov_m = solution.objective_value
    percent = (ov_m/ov) * 100
    
    r_models.loc[r_models.index[i], 'objective_value'] = ov_m
    r_models.loc[r_models.index[i], 'percent_ov'] = percent
    r_models.loc[r_models.index[i], 'feasible_models'] = "TRUE" if percent > 5 else "FALSE"


print(f"The 5% of Recon 3D objective value is {5/100*ov}")
print(f"There are {r_models['feasible_models'].eq('FALSE').sum()} models that aren't feasible because of their low objective value.\n")
r_models.head()
# Out:
# The 5% of Recon 3D objective value is 13832.493273199752
# There are 0 models that aren't feasible because of their low objective value.
#                               objective_value  percent_ov feasible_models
# GTEX-1I1GS-0011-R1a-SM-CJI43    236049.955687   85.324443            TRUE
# GTEX-1LB8K-0011-R1b-SM-EZ6MV    123348.177598   44.586386            TRUE
# GTEX-14JG1-0926-SM-5YY8W         86188.709983   31.154438            TRUE
# GTEX-1H4P4-0011-R1b-SM-CL54V    129239.238194   46.715815            TRUE
# GTEX-XMD2-1026-SM-4WWE8         107745.002714   38.946342            TRUE

# %%
fig, axes = plt.subplots(nrows = 1, ncols = 2, figsize = (15, 10))

sns.histplot(r_models["objective_value"], kde = True, color = '#C39BF1', ax = axes[0])
sns.histplot(r_models["objective_value"], kde = True, color = '#C39BF1', ax = axes[1])
plt.axvline(x = ov*(15/100), color = 'r', linestyle = '--')
plt.axvline(x = ov, color = 'r', linestyle = '--')
for ax in axes:
    ax.set_xlabel('Objective value')

# %%
plt.figure(figsize = (15, 18
                     ))

sns.histplot(r_models["objective_value"], kde = True, color = '#C39BF1')
plt.axvline(x = ov*(5/100), color = 'r', linestyle = '--')
plt.axvline(x = ov, color = 'r', linestyle = '--')
plt.text(266000, 40, "Recon 3D Objective value", rotation=90, va='center', fontsize=25, color = "r")
plt.xlabel('Objective value', fontsize = 30)
plt.ylabel('Count', fontsize = 30)
plt.xticks(fontsize=30)
plt.yticks(fontsize=30)
# Out:
# (array([ 0., 10., 20., 30., 40., 50., 60.]),
#  [Text(0, 0.0, '0'),
#   Text(0, 10.0, '10'),
#   Text(0, 20.0, '20'),
#   Text(0, 30.0, '30'),
#   Text(0, 40.0, '40'),
#   Text(0, 50.0, '50'),
#   Text(0, 60.0, '60')])

# %% [markdown]
# # RESULTS VISUALIZATION

# %% [markdown]
# ## CREATION OF THE FLUXOMES DATAFRAME

# %%
fluxes_df = pd.DataFrame(index = [model.id for model in models])

for i, solution in enumerate(solutions, start = 0):
    fluxes = solution.fluxes
    
    for reaction, flux in fluxes.items():
        if reaction not in fluxes_df.columns:
            fluxes_df[reaction] = 0.0
        
        fluxes_df.loc[fluxes_df.index[i], reaction] = flux
        fluxes_df = fluxes_df.copy()

fluxes_df.head()
# Out:
#                               10FTHF7GLUtl  10FTHF7GLUtm  10FTHFtl  \
# GTEX-1I1GS-0011-R1a-SM-CJI43           0.0           0.0       0.0
# GTEX-1LB8K-0011-R1b-SM-EZ6MV           0.0           0.0       0.0
# GTEX-14JG1-0926-SM-5YY8W               0.0           0.0       0.0
# GTEX-1H4P4-0011-R1b-SM-CL54V           0.0           0.0       0.0
# GTEX-XMD2-1026-SM-4WWE8                0.0           0.0       0.0
#
#                                  13DAMPPOX  2AMACHYD  2AMACSULT  2HBO  \
# GTEX-1I1GS-0011-R1a-SM-CJI43  0.000000e+00       0.0        0.0   0.0
# GTEX-1LB8K-0011-R1b-SM-EZ6MV  0.000000e+00       0.0        0.0   0.0
# GTEX-14JG1-0926-SM-5YY8W      0.000000e+00       0.0        0.0   0.0
# GTEX-1H4P4-0011-R1b-SM-CL54V  0.000000e+00       0.0        0.0   0.0
# GTEX-XMD2-1026-SM-4WWE8      -1.684619e-30       0.0        0.0   0.0
#
#                                      2HBt2  2OXOADOXm   2OXOADPTm  ...  \
# GTEX-1I1GS-0011-R1a-SM-CJI43  0.000000e+00        0.0 -540.644424  ...
# GTEX-1LB8K-0011-R1b-SM-EZ6MV -3.192253e-12        0.0    0.000000  ...
# GTEX-14JG1-0926-SM-5YY8W      3.513490e-12        0.0    0.000000  ...
# GTEX-1H4P4-0011-R1b-SM-CL54V  0.000000e+00        0.0    0.000000  ...
# GTEX-XMD2-1026-SM-4WWE8       0.000000e+00        0.0    0.000000  ...
#
#                               HDCA24GSc  HDCA24GSr  HDCA24Gtr  \
# GTEX-1I1GS-0011-R1a-SM-CJI43        0.0        0.0        0.0
# GTEX-1LB8K-0011-R1b-SM-EZ6MV        0.0        0.0        0.0
# GTEX-14JG1-0926-SM-5YY8W            0.0        0.0        0.0
# GTEX-1H4P4-0011-R1b-SM-CL54V        0.0        0.0        0.0
# GTEX-XMD2-1026-SM-4WWE8             0.0        0.0        0.0
#
#                               EX_lstn1gluc[e]  LSTN1GLUChr  LSTN1GLUCtev  \
# GTEX-1I1GS-0011-R1a-SM-CJI43              0.0          0.0           0.0
# GTEX-1LB8K-0011-R1b-SM-EZ6MV              0.0          0.0           0.0
# GTEX-14JG1-0926-SM-5YY8W                  0.0          0.0           0.0
# GTEX-1H4P4-0011-R1b-SM-CL54V              0.0          0.0           0.0
# GTEX-XMD2-1026-SM-4WWE8                   0.0          0.0           0.0
#
#                               LSTN1GLUCitr  r1955  GLNATB0tc  RE0453C
# GTEX-1I1GS-0011-R1a-SM-CJI43           0.0    0.0        0.0      0.0
# GTEX-1LB8K-0011-R1b-SM-EZ6MV           0.0    0.0        0.0      0.0
# GTEX-14JG1-0926-SM-5YY8W               0.0    0.0        0.0      0.0
# GTEX-1H4P4-0011-R1b-SM-CL54V           0.0    0.0        0.0      0.0
# GTEX-XMD2-1026-SM-4WWE8                0.0    0.0        0.0      0.0
#
# [5 rows x 8124 columns]

# %% [markdown]
# ## UMAP PROJECTION

# %%
c_labs = pd.read_csv('/Users/claudiavicentecomorera/Desktop/TFG/Data/RNA_seq/clabs_bulk200.csv')
d_clabs = {}

for index, row in c_labs.iterrows():
    sample = row['Sample_Name']
    tissue = row['Cluster_Label']
    if tissue in d_clabs:
        d_clabs[tissue].append(sample)
    else:
        d_clabs[tissue] = [sample]

# %%
l = []
l_labs = []
for key, value in d_clabs.items():
    if key == 'hippocampus':
        l.append(plt.Line2D([0], [0], marker='o', color='w', markerfacecolor='r', markersize=10))
    elif key == 'lung':
        l.append(plt.Line2D([0], [0], marker='o', color='w', markerfacecolor='b', markersize=10))
    l_labs.append(key)

# %%
colors = []

for sample in fluxes_df.index:
    for tissue in d_clabs:
        for samples in d_clabs[tissue]:
            if sample in samples:
                if tissue == 'hippocampus':
                    colors.append('r')
                elif tissue == 'lung':
                    colors.append('b')

# %%
reducer = umap.UMAP()
embedding = reducer.fit_transform(fluxes_df)

plt.scatter(embedding[:, 0], embedding[:, 1], c = colors) 
plt.legend(l, l_labs)
plt.title('UMAP of 200 models fluxes distributions')
plt.xlabel('UMAP 1')
plt.ylabel('UMAP 2')
plt.show()

# %%
d_ov = dict(zip(r_models.index, r_models['percent_ov']))

plt.scatter(embedding[:, 0], embedding[:, 1], c = [d_ov.get(index, -1) for index in fluxes_df.index], cmap = "viridis")
plt.colorbar(label = 'Objective value')  
plt.title('UMAP of 200 models fluxes distributions')
plt.xlabel('UMAP 1')
plt.ylabel('UMAP 2')
plt.show()

# %%
heatmap = sns.heatmap(fluxes_df, cmap = 'seismic', xticklabels = False, yticklabels = False, center = 0)
cbar = heatmap.collections[0].colorbar
cbar.ax.set_ylabel('Flux')  
plt.title('Heatmap of fluxes distribution across samples')
plt.xlabel('Reactions')
plt.ylabel('Cells')
# Out:
# Text(74.44444444444444, 0.5, 'Cells')

# %% [markdown]
# # RESULTS VISUALIZATION WITH TRANSFORMED FLUXES

# %%
def flux_transformer(v):

    '''
    This function transforms fluxes into log2 scale with three additions:
    - zero values are kept.
    - values between 0 and 2 are adjusted to fit below one.
    - negative fluxes are considered. 
    '''

    def adjusted(v):
        new = (np.log2(v + 0.125) + 3) / 4
        return np.min([new, 1])

    if v == 0:
        vprime = 0
    elif v > 0:
        if v < 2:
            vprime = adjusted(v)
        else:
            vprime = np.log2(v)
    elif v < 0:
        v = np.abs(v)
        if v < 2:
            vprime = -adjusted(v)
        else:
            vprime = -np.log2(v)
    else:
        raise ValueError('found value not considered')

    return vprime

# %%
t_fluxes_df = fluxes_df.applymap(flux_transformer)
t_fluxes_df
# Out:
#                               10FTHF7GLUtl  10FTHF7GLUtm  10FTHFtl  13DAMPPOX  \
# GTEX-1I1GS-0011-R1a-SM-CJI43           0.0           0.0       0.0        0.0
# GTEX-1LB8K-0011-R1b-SM-EZ6MV           0.0           0.0       0.0        0.0
# GTEX-14JG1-0926-SM-5YY8W               0.0           0.0       0.0        0.0
# GTEX-1H4P4-0011-R1b-SM-CL54V           0.0           0.0       0.0        0.0
# GTEX-XMD2-1026-SM-4WWE8                0.0           0.0       0.0       -0.0
# ...                                    ...           ...       ...        ...
# GTEX-ZTPG-0926-SM-5O99H                0.0           0.0       0.0        0.0
# GTEX-13FLW-0011-R1b-SM-5LZX2           0.0           0.0       0.0        0.0
# GTEX-1FIGZ-0326-SM-7RHGT               0.0           0.0       0.0        0.0
# GTEX-1JMQJ-2126-SM-CNPPA               0.0           0.0       0.0        0.0
# GTEX-P44H-1126-SM-48TBU                0.0           0.0       0.0        0.0
#
#                               2AMACHYD  2AMACSULT  2HBO         2HBt2  \
# GTEX-1I1GS-0011-R1a-SM-CJI43       0.0        0.0   0.0  0.000000e+00
# GTEX-1LB8K-0011-R1b-SM-EZ6MV       0.0        0.0   0.0 -9.210854e-12
# GTEX-14JG1-0926-SM-5YY8W           0.0        0.0   0.0  1.013778e-11
# GTEX-1H4P4-0011-R1b-SM-CL54V       0.0        0.0   0.0  0.000000e+00
# GTEX-XMD2-1026-SM-4WWE8            0.0        0.0   0.0  0.000000e+00
# ...                                ...        ...   ...           ...
# GTEX-ZTPG-0926-SM-5O99H            0.0        0.0   0.0  0.000000e+00
# GTEX-13FLW-0011-R1b-SM-5LZX2       0.0        0.0   0.0  0.000000e+00
# GTEX-1FIGZ-0326-SM-7RHGT           0.0        0.0   0.0  0.000000e+00
# GTEX-1JMQJ-2126-SM-CNPPA           0.0        0.0   0.0  0.000000e+00
# GTEX-P44H-1126-SM-48TBU            0.0        0.0   0.0  0.000000e+00
#
#                               2OXOADOXm  2OXOADPTm  ...  HDCA24GSc  HDCA24GSr  \
# GTEX-1I1GS-0011-R1a-SM-CJI43        0.0  -9.078536  ...          0          0
# GTEX-1LB8K-0011-R1b-SM-EZ6MV        0.0   0.000000  ...          0          0
# GTEX-14JG1-0926-SM-5YY8W            0.0   0.000000  ...          0          0
# GTEX-1H4P4-0011-R1b-SM-CL54V        0.0   0.000000  ...          0          0
# GTEX-XMD2-1026-SM-4WWE8             0.0   0.000000  ...          0          0
# ...                                 ...        ...  ...        ...        ...
# GTEX-ZTPG-0926-SM-5O99H             0.0   0.000000  ...          0          0
# GTEX-13FLW-0011-R1b-SM-5LZX2        0.0   0.000000  ...          0          0
# GTEX-1FIGZ-0326-SM-7RHGT            0.0   0.000000  ...          0          0
# GTEX-1JMQJ-2126-SM-CNPPA            0.0   0.000000  ...          0          0
# GTEX-P44H-1126-SM-48TBU             0.0   0.000000  ...          0          0
#
#                               HDCA24Gtr  EX_lstn1gluc[e]  LSTN1GLUChr  \
# GTEX-1I1GS-0011-R1a-SM-CJI43          0                0            0
# GTEX-1LB8K-0011-R1b-SM-EZ6MV          0                0            0
# GTEX-14JG1-0926-SM-5YY8W              0                0            0
# GTEX-1H4P4-0011-R1b-SM-CL54V          0                0            0
# GTEX-XMD2-1026-SM-4WWE8               0                0            0
# ...                                 ...              ...          ...
# GTEX-ZTPG-0926-SM-5O99H               0                0            0
# GTEX-13FLW-0011-R1b-SM-5LZX2          0                0            0
# GTEX-1FIGZ-0326-SM-7RHGT              0                0            0
# GTEX-1JMQJ-2126-SM-CNPPA              0                0            0
# GTEX-P44H-1126-SM-48TBU               0                0            0
#
#                               LSTN1GLUCtev  LSTN1GLUCitr  r1955  GLNATB0tc  \
# GTEX-1I1GS-0011-R1a-SM-CJI43             0             0      0          0
# GTEX-1LB8K-0011-R1b-SM-EZ6MV             0             0      0          0
# GTEX-14JG1-0926-SM-5YY8W                 0             0      0          0
# GTEX-1H4P4-0011-R1b-SM-CL54V             0             0      0          0
# GTEX-XMD2-1026-SM-4WWE8                  0             0      0          0
# ...                                    ...           ...    ...        ...
# GTEX-ZTPG-0926-SM-5O99H                  0             0      0          0
# GTEX-13FLW-0011-R1b-SM-5LZX2             0             0      0          0
# GTEX-1FIGZ-0326-SM-7RHGT                 0             0      0          0
# GTEX-1JMQJ-2126-SM-CNPPA                 0             0      0          0
# GTEX-P44H-1126-SM-48TBU                  0             0      0          0
#
#                               RE0453C
# GTEX-1I1GS-0011-R1a-SM-CJI43        0
# GTEX-1LB8K-0011-R1b-SM-EZ6MV        0
# GTEX-14JG1-0926-SM-5YY8W            0
# GTEX-1H4P4-0011-R1b-SM-CL54V        0
# GTEX-XMD2-1026-SM-4WWE8             0
# ...                               ...
# GTEX-ZTPG-0926-SM-5O99H             0
# GTEX-13FLW-0011-R1b-SM-5LZX2        0
# GTEX-1FIGZ-0326-SM-7RHGT            0
# GTEX-1JMQJ-2126-SM-CNPPA            0
# GTEX-P44H-1126-SM-48TBU             0
#
# [200 rows x 8124 columns]

# %%
plt.figure(figsize = (10, 8))
reducer = umap.UMAP()
embedding = reducer.fit_transform(t_fluxes_df)

plt.scatter(embedding[:, 0], embedding[:, 1], c = colors) 
plt.legend(l, l_labs, fontsize=20)
#plt.title('UMAP of 200 models transformed fluxes distributions')
plt.xlabel('UMAP 1', fontsize = 25)
plt.ylabel('UMAP 2', fontsize = 25)
plt.xticks(fontsize=25)
plt.yticks(fontsize=25)
plt.show()

# %%
plt.figure(figsize = (10, 8))
plt.scatter(embedding[:, 0], embedding[:, 1], c = [d_ov.get(index, -1) for index in fluxes_df.index], cmap = "viridis")
cbar = plt.colorbar()  
cbar.ax.tick_params(labelsize=20)
cbar.set_label('Objective value', fontsize=25)
#plt.title('UMAP of 200 models transformed fluxes distributions')
plt.xlabel('UMAP 1', fontsize = 25)
plt.ylabel('UMAP 2', fontsize = 25)
plt.xticks(fontsize=25)
plt.yticks(fontsize=25)
plt.show()

# %%
heatmap = sns.heatmap(t_fluxes_df, cmap = 'seismic', xticklabels = False, yticklabels = False, center = 0)
cbar = heatmap.collections[0].colorbar
cbar.ax.set_ylabel('Transformed flux')  
plt.title('Heatmap of transformed fluxes distribution across cells')
plt.xlabel('Reactions')
plt.ylabel('Cells')
# Out:
# Text(74.44444444444444, 0.5, 'Cells')

# %% [markdown]
# # RESULTS VISUALIZATION WITH THE MOST VARIABLE FLUXES

# %%
variability = t_fluxes_df.std(axis = 0)

s_cols = variability.sort_values(ascending = False)
s_cols = s_cols.head(200)
s_colnames = s_cols.index
var_df = t_fluxes_df[s_colnames]
var_df
# Out:
#                                     GLUt2m         UREAt           FUM  \
# GTEX-1I1GS-0011-R1a-SM-CJI43  9.965784e+00  9.965784e+00  6.293473e+00
# GTEX-1LB8K-0011-R1b-SM-EZ6MV  7.941323e+00  9.320777e+00  7.989838e+00
# GTEX-14JG1-0926-SM-5YY8W      9.965784e+00 -9.533084e+00 -7.514595e+00
# GTEX-1H4P4-0011-R1b-SM-CL54V  9.965784e+00  9.513744e+00  9.374282e+00
# GTEX-XMD2-1026-SM-4WWE8      -1.389366e-11  0.000000e+00  3.962386e-13
# ...                                    ...           ...           ...
# GTEX-ZTPG-0926-SM-5O99H      -1.091127e-12  6.975257e+00  7.775891e+00
# GTEX-13FLW-0011-R1b-SM-5LZX2  8.191156e+00  8.447687e-13  0.000000e+00
# GTEX-1FIGZ-0326-SM-7RHGT     -9.965784e+00  9.965784e+00  0.000000e+00
# GTEX-1JMQJ-2126-SM-CNPPA      9.965784e+00 -9.965784e+00 -9.322065e+00
# GTEX-P44H-1126-SM-48TBU      -7.661401e+00  9.965784e+00 -7.893686e-13
#
#                                    TPI         LDH_L     r0407          FUMm  \
# GTEX-1I1GS-0011-R1a-SM-CJI43 -6.398703  8.447687e-13 -6.398703  9.863791e+00
# GTEX-1LB8K-0011-R1b-SM-EZ6MV  9.706227 -9.215718e+00  8.363307  8.004878e+00
# GTEX-14JG1-0926-SM-5YY8W      8.380822 -9.965784e+00  8.380822  8.123900e+00
# GTEX-1H4P4-0011-R1b-SM-CL54V  8.384195 -9.965784e+00  8.374052  7.560194e+00
# GTEX-XMD2-1026-SM-4WWE8       7.398740 -9.965784e+00  6.673719  0.000000e+00
# ...                                ...           ...       ...           ...
# GTEX-ZTPG-0926-SM-5O99H      -8.212516 -9.495062e+00 -8.521587  9.480357e+00
# GTEX-13FLW-0011-R1b-SM-5LZX2 -7.182228 -9.965784e+00 -7.182228  9.696090e+00
# GTEX-1FIGZ-0326-SM-7RHGT     -7.346921 -9.965784e+00 -5.476602  9.965784e+00
# GTEX-1JMQJ-2126-SM-CNPPA      8.380822 -8.317366e+00  8.380822  9.965784e+00
# GTEX-P44H-1126-SM-48TBU       7.398740 -9.920802e+00  6.673719  7.924772e-13
#
#                               EX_gly[e]     EX_so4[e]  EX_urea[e]  ...  \
# GTEX-1I1GS-0011-R1a-SM-CJI43   9.965784 -9.965784e+00   -9.965784  ...
# GTEX-1LB8K-0011-R1b-SM-EZ6MV  -6.890733  0.000000e+00   -9.320777  ...
# GTEX-14JG1-0926-SM-5YY8W       0.000000  0.000000e+00   -8.017510  ...
# GTEX-1H4P4-0011-R1b-SM-CL54V   9.795261  7.567874e+00   -9.513744  ...
# GTEX-XMD2-1026-SM-4WWE8       -6.807502  9.965784e+00   -9.965784  ...
# ...                                 ...           ...         ...  ...
# GTEX-ZTPG-0926-SM-5O99H        0.000000 -9.478699e+00   -6.975257  ...
# GTEX-13FLW-0011-R1b-SM-5LZX2  -7.407865  6.609158e-13   -9.965784  ...
# GTEX-1FIGZ-0326-SM-7RHGT       0.000000 -9.885922e+00   -9.965784  ...
# GTEX-1JMQJ-2126-SM-CNPPA       0.000000  0.000000e+00    6.632560  ...
# GTEX-P44H-1126-SM-48TBU        0.000000  9.965784e+00   -9.965784  ...
#
#                                    MMTSADm    NAt3_1     r0191  sink_pro_L[c]  \
# GTEX-1I1GS-0011-R1a-SM-CJI43  0.000000e+00  0.000000  0.000000      -9.965784
# GTEX-1LB8K-0011-R1b-SM-EZ6MV  7.941323e+00  0.000000  8.061669       0.000000
# GTEX-14JG1-0926-SM-5YY8W      0.000000e+00  0.000000  0.000000       0.000000
# GTEX-1H4P4-0011-R1b-SM-CL54V  0.000000e+00  0.000000  8.732435      -9.647579
# GTEX-XMD2-1026-SM-4WWE8       2.796430e-11  8.367749  0.000000       0.000000
# ...                                    ...       ...       ...            ...
# GTEX-ZTPG-0926-SM-5O99H       0.000000e+00  0.000000  0.000000      -6.677744
# GTEX-13FLW-0011-R1b-SM-5LZX2  0.000000e+00 -9.067505  0.000000      -6.744883
# GTEX-1FIGZ-0326-SM-7RHGT      9.965784e+00  0.000000  0.000000       9.806760
# GTEX-1JMQJ-2126-SM-CNPPA      0.000000e+00  0.000000  0.000000       0.000000
# GTEX-P44H-1126-SM-48TBU       1.078471e-12 -9.965784  0.000000      -6.544455
#
#                                 GLNtN1  HMR_2281  C140CPT1  HMR_2611  \
# GTEX-1I1GS-0011-R1a-SM-CJI43  0.000000  0.000000  0.000000  0.000000
# GTEX-1LB8K-0011-R1b-SM-EZ6MV  0.000000  9.965784 -9.965784  9.965784
# GTEX-14JG1-0926-SM-5YY8W      9.714108  0.000000  0.000000  0.000000
# GTEX-1H4P4-0011-R1b-SM-CL54V  6.460612  9.965784 -9.965784  9.965784
# GTEX-XMD2-1026-SM-4WWE8       0.000000  0.000000  0.000000  0.000000
# ...                                ...       ...       ...       ...
# GTEX-ZTPG-0926-SM-5O99H       9.355078  0.000000  0.000000  0.000000
# GTEX-13FLW-0011-R1b-SM-5LZX2  0.000000  0.000000  0.000000  0.000000
# GTEX-1FIGZ-0326-SM-7RHGT      9.507716  0.000000  0.000000  0.000000
# GTEX-1JMQJ-2126-SM-CNPPA      0.000000  0.000000  0.000000  0.000000
# GTEX-P44H-1126-SM-48TBU       0.000000  0.000000  0.000000  0.000000
#
#                               sink_phe_L[c]   RE2426C
# GTEX-1I1GS-0011-R1a-SM-CJI43       0.000000  0.000000
# GTEX-1LB8K-0011-R1b-SM-EZ6MV       0.000000  0.000000
# GTEX-14JG1-0926-SM-5YY8W           0.000000  0.000000
# GTEX-1H4P4-0011-R1b-SM-CL54V       0.000000  0.000000
# GTEX-XMD2-1026-SM-4WWE8            0.000000 -8.804799
# ...                                     ...       ...
# GTEX-ZTPG-0926-SM-5O99H            0.000000 -9.590804
# GTEX-13FLW-0011-R1b-SM-5LZX2       0.000000  0.000000
# GTEX-1FIGZ-0326-SM-7RHGT          -6.036795 -7.459616
# GTEX-1JMQJ-2126-SM-CNPPA           0.000000  0.000000
# GTEX-P44H-1126-SM-48TBU           -5.923005 -7.965784
#
# [200 rows x 200 columns]

# %%
reducer = umap.UMAP()
embedding = reducer.fit_transform(var_df)

plt.scatter(embedding[:, 0], embedding[:, 1], c = colors) 
plt.legend(l, l_labs)

plt.title('UMAP of 200 models transformed fluxes distributions')
plt.xlabel('UMAP 1')
plt.ylabel('UMAP 2')
plt.show()

# %%
plt.scatter(embedding[:, 0], embedding[:, 1], c = [d_ov.get(index, -1) for index in fluxes_df.index], cmap = "viridis")
plt.colorbar(label = 'Objective value')  
plt.title('UMAP of 200 models transformed fluxes distributions')
plt.xlabel('UMAP 1')
plt.ylabel('UMAP 2')
plt.show()

# %%
heatmap = sns.heatmap(var_df, cmap = 'seismic', xticklabels = False, yticklabels = False, center = 0)
cbar = heatmap.collections[0].colorbar
cbar.ax.set_ylabel('Transformed flux')  
plt.title('Heatmap of transformed fluxes distribution across cells')
plt.xlabel('Reactions')
plt.ylabel('Cells')
# Out:
# Text(74.44444444444444, 0.5, 'Cells')

# %%
sns.clustermap(var_df, cmap = 'seismic', xticklabels = False, yticklabels = False, row_colors = colors)
# Out:
# /Users/claudiavicentecomorera/anaconda3/lib/python3.11/site-packages/seaborn/matrix.py:560: UserWarning: Clustering large matrix with scipy. Installing `fastcluster` may give better performance.
#   warnings.warn(msg)
# /Users/claudiavicentecomorera/anaconda3/lib/python3.11/site-packages/seaborn/matrix.py:560: UserWarning: Clustering large matrix with scipy. Installing `fastcluster` may give better performance.
#   warnings.warn(msg)
